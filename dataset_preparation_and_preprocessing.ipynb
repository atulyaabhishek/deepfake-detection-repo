# %% [markdown]
# # Building a Deepfake Detector using Machine Learning Models
# This notebook demonstrates the development of a deepfake detection system using multiple pre-trained **CNN (Convolutional Neural Network)** models (**ResNet**, **EfficientNet** and **Xception**) combined with **LSTM (Long Short-Term Memory)** for temporal analysis. The dataset used is **FaceForensics++**, **DFDC** and **Celeb-DF (v2)** with `OpenCV` utilized for video frame extraction and preprocessing and `dlib` employed for face detection and cropping.

# %% [markdown]
# ## 1. Importing Libraries and Setup
# Importing all necessary libraries at the top to ensures better organization, easy debugging and smooth execution of the entire pipeline.

# %%
import os
import sys
import cv2
import numpy as np
import pandas as pd
import shutil
import dlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, Dropout, LSTM, TimeDistributed, Concatenate
from tensorflow.keras.applications import ResNet50, EfficientNetV2B0, Xception
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

# %% [markdown]
# ### 1.1 Checking TensorFlow GPU Support and Listing Available GPUs

# %%
import tensorflow as tf

# Check if TensorFlow is built with CUDA support and list GPUs
print("TensorFlow CUDA Support:", tf.test.is_built_with_cuda())
gpus = tf.config.list_physical_devices('GPU')
print("Num GPUs Available:", len(gpus))

if gpus:
    for i, gpu in enumerate(gpus):
        print(f"GPU {i}: {tf.config.experimental.get_device_details(gpu)['device_name']}")
else:
    print("No GPU detected.")
# Out:
# TensorFlow CUDA Support: True
# Num GPUs Available: 1
# GPU 0: NVIDIA GeForce 940MX

# %% [markdown]
# ### 1.2 Configuring GPU Memory Growth
# To ensure TensorFlow uses GPU resources effectively.

# %%
# Enable GPU memory growth to prevent allocation issues
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    for gpu in physical_devices:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Enabled memory growth for: {tf.config.experimental.get_device_details(gpu)['device_name']}")
else:
    print("No GPU devices found. Ensure proper GPU setup.")
# Out:
# Enabled memory growth for: NVIDIA GeForce 940MX

# %% [markdown]
# ## 2. Dataset Preparation
# Preparing the dataset for video frame extraction, face detection and cropping followed by organizing the data into structured train and validation directories.

# %% [markdown]
# ### 2.1 Defining Paths and Creating Directories for the Training Dataset

# %%
# Defining base directory where the dataset resides
base_dir = os.getcwd() # Current working directory where my Jupyter Notebook is located

# Defining paths for dataset directories
real_videos_dir = os.path.join(base_dir, "Datasets", "FaceForensic++", "real")
fake_videos_dir = os.path.join(base_dir, "Datasets", "FaceForensic++", "fake")

# Defining paths for cropped faces directories
real_faces_dir = os.path.join(base_dir, "Cropped_Faces", "real")
fake_faces_dir = os.path.join(base_dir, "Cropped_Faces", "fake")

# Defining paths for training and validation directories
train_dir = os.path.join(base_dir, "Cropped_Faces", "train")
val_dir = os.path.join(base_dir, "Cropped_Faces", "val")

# Creating necessary directories if they don’t already exist
os.makedirs(real_faces_dir, exist_ok=True)
os.makedirs(fake_faces_dir, exist_ok=True)
os.makedirs(os.path.join(train_dir, "real"), exist_ok=True)
os.makedirs(os.path.join(train_dir, "fake"), exist_ok=True)
os.makedirs(os.path.join(val_dir, "real"), exist_ok=True)
os.makedirs(os.path.join(val_dir, "fake"), exist_ok=True)

print(f"Directories for processing and output:")
print(f"Real Videos: {real_videos_dir}")
print(f"Fake Videos: {fake_videos_dir}")
print(f"Real Faces: {real_faces_dir}")
print(f"Fake Faces: {fake_faces_dir}")
print(f"Train Directory: {train_dir}")
print(f"Validation Directory: {val_dir}")
# Out:
# Directories for processing and output:
# Real Videos: C:\Users\atul\Datasets\FaceForensic++\real
# Fake Videos: C:\Users\atul\Datasets\FaceForensic++\fake
# Real Faces: C:\Users\atul\Cropped_Faces\real
# Fake Faces: C:\Users\atul\Cropped_Faces\fake
# Train Directory: C:\Users\atul\Cropped_Faces\train
# Validation Directory: C:\Users\atul\Cropped_Faces\val

# %% [markdown]
# ### 2.2 Face Detection and Cropping from Dataset for Train/Val

# %%
# Initialize the face detector
detector = dlib.get_frontal_face_detector()

def crop_faces(input_dir, output_dir, dataset_name, face_size=(224, 224), is_real=True):
    """
    Detects and crops faces from videos in the input directory.
    Cropped faces are saved in specific folders with unique names in the output directory.

    Args:
    - input_dir (str): Path to the directory containing videos.
    - output_dir (str): Path to the directory to save cropped face images.
    - dataset_name (str): Prefix for naming folders and files (e.g., dataset name).
    - face_size (tuple): Dimensions to resize each face (width, height).
    - is_real (bool): Indicates whether the videos are from the "real" or "fake" category.
    """
    # Check if input and output directories exist
    if not os.path.exists(input_dir):
        print(f"Input directory {input_dir} does not exist. Skipping.")
        return
    os.makedirs(output_dir, exist_ok=True)

    # Supported video formats
    supported_formats = (".mp4", ".avi", ".mkv", ".mov")

    # Initialize folder counter
    folder_counter = 0

    # Looping through each file in the input directory
    for file in os.listdir(input_dir):
        if file.lower().endswith(supported_formats):  # Process only supported video files
            video_name = os.path.splitext(file)[0]  # Extract the video name (without extension)

            # Generate a unique folder name based on the dataset name and category
            category = "real" if is_real else "fake"
            folder_name = f"{dataset_name}_{category}{folder_counter}"
            folder_counter += 1

            # Create the unique folder
            folder_path = os.path.join(output_dir, folder_name)

            # Skip already processed videos
            if os.path.exists(folder_path) and len(os.listdir(folder_path)) > 0:
                print(f"Skipping already processed video: {file}")
                continue

            os.makedirs(folder_path, exist_ok=True)

            video_path = os.path.join(input_dir, file)
            cap = cv2.VideoCapture(video_path)  # Open the video file

            if not cap.isOpened():
                print(f"Failed to open video {file}. Skipping.")
                continue

            frame_count = 0
            cropped_count = 0  # Counter for cropped faces

            # Looping through frames in the video
            while cap.isOpened():
                ret, frame = cap.read()  # Read a frame
                if not ret:  # Exit when no more frames
                    break

                frame_count += 1
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert frame to grayscale
                faces = detector(gray)  # Detect faces in the frame

                # Save each detected face
                for i, face in enumerate(faces):
                    x, y, w, h = face.left(), face.top(), face.width(), face.height()

                    # Validate face coordinates to ensure they are within the frame bounds
                    x = max(0, x)
                    y = max(0, y)
                    w = min(frame.shape[1] - x, w)
                    h = min(frame.shape[0] - y, h)

                    if w <= 0 or h <= 0:  # Check if the cropped region is valid
                        print(f"Invalid face region in frame {frame_count}, video {file}. Skipping.")
                        continue

                    # Crop the face from the frame
                    cropped_face = frame[y:y+h, x:x+w]

                    # Resize the cropped face to the specified size
                    cropped_face = cv2.resize(cropped_face, face_size)

                    # Generate a unique filename for the cropped face
                    file_name = f"{folder_name}_frame{frame_count}_face{i}.jpg"
                    save_path = os.path.join(folder_path, file_name)

                    # Save the cropped face
                    cv2.imwrite(save_path, cropped_face)
                    cropped_count += 1  # Increment the cropped face counter

            cap.release()  # Release the video capture object
            print(f"Processed {file}: {cropped_count} face(s) cropped into {folder_name}.")
    print("--- Face cropping complete ---")

# Process real videos
print("--- Processing Real videos from FaceForensic++ dataset ---")
crop_faces(real_videos_dir, real_faces_dir, "FF", is_real=True)

# Process fake videos
print("\n--- Processing Fake videos from FaceForensic++ dataset ---")
crop_faces(fake_videos_dir, fake_faces_dir, "FF", is_real=False)
# Out:
# --- Processing Real videos from FaceForensic++ dataset ---
# Processed 01__exit_phone_room.mp4: 255 face(s) cropped into FF_real0.
# Processed 01__hugging_happy.mp4: 702 face(s) cropped into FF_real1.
# Processed 01__kitchen_pan.mp4: 534 face(s) cropped into FF_real2.
# Processed 01__kitchen_still.mp4: 800 face(s) cropped into FF_real3.
# Processed 01__meeting_serious.mp4: 1199 face(s) cropped into FF_real4.
# Processed 01__outside_talking_pan_laughing.mp4: 599 face(s) cropped into FF_real5.
# Processed 01__outside_talking_still_laughing.mp4: 841 face(s) cropped into FF_real6.
# Processed 01__podium_speech_happy.mp4: 902 face(s) cropped into FF_real7.
# Processed 01__secret_conversation.mp4: 1000 face(s) cropped into FF_real8.
# Processed 01__talking_against_wall.mp4: 860 face(s) cropped into FF_real9.
# Processed 01__talking_angry_couch.mp4: 1489 face(s) cropped into FF_real10.
# Processed 01__walking_and_outside_surprised.mp4: 2032 face(s) cropped into FF_real11.
# Processed 01__walking_down_indoor_hall_disgust.mp4: 1616 face(s) cropped into FF_real12.
# Processed 01__walking_down_street_outside_angry.mp4: 480 face(s) cropped into FF_real13.
# Processed 01__walking_outside_cafe_disgusted.mp4: 294 face(s) cropped into FF_real14.
# Processed 01__walk_down_hall_angry.mp4: 254 face(s) cropped into FF_real15.
# Processed 02__exit_phone_room.mp4: 303 face(s) cropped into FF_real16.
# Processed 02__hugging_happy.mp4: 771 face(s) cropped into FF_real17.
# Processed 02__kitchen_pan.mp4: 571 face(s) cropped into FF_real18.
# Processed 02__kitchen_still.mp4: 855 face(s) cropped into FF_real19.
# Processed 02__meeting_serious.mp4: 1476 face(s) cropped into FF_real20.
# Processed 02__outside_talking_pan_laughing.mp4: 645 face(s) cropped into FF_real21.
# Processed 02__outside_talking_still_laughing.mp4: 819 face(s) cropped into FF_real22.
# Processed 02__podium_speech_happy.mp4: 1076 face(s) cropped into FF_real23.
# Processed 02__secret_conversation.mp4: 956 face(s) cropped into FF_real24.
# Processed 02__talking_against_wall.mp4: 990 face(s) cropped into FF_real25.
# Processed 02__talking_angry_couch.mp4: 1292 face(s) cropped into FF_real26.
# Processed 02__walking_and_outside_surprised.mp4: 2032 face(s) cropped into FF_real27.
# Processed 02__walking_down_indoor_hall_disgust.mp4: 1610 face(s) cropped into FF_real28.
# Processed 02__walking_down_street_outside_angry.mp4: 564 face(s) cropped into FF_real29.
# Processed 02__walking_outside_cafe_disgusted.mp4: 559 face(s) cropped into FF_real30.
# Processed 02__walk_down_hall_angry.mp4: 245 face(s) cropped into FF_real31.
# Processed 03__exit_phone_room.mp4: 622 face(s) cropped into FF_real32.
# Processed 03__hugging_happy.mp4: 813 face(s) cropped into FF_real33.
# Processed 03__kitchen_pan.mp4: 531 face(s) cropped into FF_real34.
# Processed 03__kitchen_still.mp4: 957 face(s) cropped into FF_real35.
# Processed 03__meeting_serious.mp4: 1035 face(s) cropped into FF_real36.
# Processed 03__outside_talking_pan_laughing.mp4: 712 face(s) cropped into FF_real37.
# Processed 03__outside_talking_still_laughing.mp4: 948 face(s) cropped into FF_real38.
# Processed 03__podium_speech_happy.mp4: 840 face(s) cropped into FF_real39.
# Processed 03__secret_conversation.mp4: 962 face(s) cropped into FF_real40.
# Processed 03__talking_against_wall.mp4: 910 face(s) cropped into FF_real41.
# Processed 03__talking_angry_couch.mp4: 1452 face(s) cropped into FF_real42.
# Processed 03__walking_and_outside_surprised.mp4: 2282 face(s) cropped into FF_real43.
# Processed 03__walking_down_indoor_hall_disgust.mp4: 2925 face(s) cropped into FF_real44.
# Processed 03__walking_down_street_outside_angry.mp4: 1079 face(s) cropped into FF_real45.
# Processed 03__walking_outside_cafe_disgusted.mp4: 707 face(s) cropped into FF_real46.
# Processed 03__walk_down_hall_angry.mp4: 476 face(s) cropped into FF_real47.
# Processed 04__exit_phone_room.mp4: 384 face(s) cropped into FF_real48.
# Processed 04__kitchen_pan.mp4: 477 face(s) cropped into FF_real49.
# Processed 04__kitchen_still.mp4: 840 face(s) cropped into FF_real50.
# Processed 04__outside_talking_pan_laughing.mp4: 787 face(s) cropped into FF_real51.
# Processed 04__outside_talking_still_laughing.mp4: 815 face(s) cropped into FF_real52.
# Processed 04__podium_speech_happy.mp4: 932 face(s) cropped into FF_real53.
# Processed 04__secret_conversation.mp4: 774 face(s) cropped into FF_real54.
# Processed 04__talking_against_wall.mp4: 900 face(s) cropped into FF_real55.
# Processed 04__talking_angry_couch.mp4: 1380 face(s) cropped into FF_real56.
# Processed 04__walking_down_street_outside_angry.mp4: 500 face(s) cropped into FF_real57.
# Processed 04__walking_outside_cafe_disgusted.mp4: 401 face(s) cropped into FF_real58.
# Processed 04__walk_down_hall_angry.mp4: 217 face(s) cropped into FF_real59.
# Processed 05__exit_phone_room.mp4: 415 face(s) cropped into FF_real60.
# Processed 05__hugging_happy.mp4: 546 face(s) cropped into FF_real61.
# Processed 05__kitchen_pan.mp4: 649 face(s) cropped into FF_real62.
# Processed 05__kitchen_still.mp4: 875 face(s) cropped into FF_real63.
# Processed 05__outside_talking_pan_laughing.mp4: 731 face(s) cropped into FF_real64.
# Processed 05__outside_talking_still_laughing.mp4: 921 face(s) cropped into FF_real65.
# Processed 05__podium_speech_happy.mp4: 1081 face(s) cropped into FF_real66.
# Processed 05__talking_against_wall.mp4: 835 face(s) cropped into FF_real67.
# Processed 05__walking_down_street_outside_angry.mp4: 674 face(s) cropped into FF_real68.
# Processed 05__walking_outside_cafe_disgusted.mp4: 611 face(s) cropped into FF_real69.
# Processed 05__walk_down_hall_angry.mp4: 465 face(s) cropped into FF_real70.
# Processed 06__exit_phone_room.mp4: 272 face(s) cropped into FF_real71.
# Processed 06__hugging_happy.mp4: 881 face(s) cropped into FF_real72.
# Processed 06__kitchen_pan.mp4: 685 face(s) cropped into FF_real73.
# Processed 06__kitchen_still.mp4: 915 face(s) cropped into FF_real74.
# Processed 06__outside_talking_pan_laughing.mp4: 665 face(s) cropped into FF_real75.
# Processed 06__outside_talking_still_laughing.mp4: 843 face(s) cropped into FF_real76.
# Processed 06__podium_speech_happy.mp4: 1252 face(s) cropped into FF_real77.
# Processed 06__talking_against_wall.mp4: 845 face(s) cropped into FF_real78.
# Processed 06__talking_angry_couch.mp4: 1179 face(s) cropped into FF_real79.
# Processed 06__walking_and_outside_surprised.mp4: 1587 face(s) cropped into FF_real80.
# Processed 06__walking_down_indoor_hall_disgust.mp4: 1996 face(s) cropped into FF_real81.
# Processed 06__walking_down_street_outside_angry.mp4: 601 face(s) cropped into FF_real82.
# Processed 06__walking_outside_cafe_disgusted.mp4: 354 face(s) cropped into FF_real83.
# Processed 06__walk_down_hall_angry.mp4: 321 face(s) cropped into FF_real84.
# Processed 07__exit_phone_room.mp4: 512 face(s) cropped into FF_real85.
# Processed 07__hugging_happy.mp4: 857 face(s) cropped into FF_real86.
# Processed 07__kitchen_pan.mp4: 584 face(s) cropped into FF_real87.
# Processed 07__kitchen_still.mp4: 840 face(s) cropped into FF_real88.
# Processed 07__outside_talking_pan_laughing.mp4: 697 face(s) cropped into FF_real89.
# Processed 07__outside_talking_still_laughing.mp4: 860 face(s) cropped into FF_real90.
# Processed 07__podium_speech_happy.mp4: 1096 face(s) cropped into FF_real91.
# Processed 07__secret_conversation.mp4: 199 face(s) cropped into FF_real92.
# Processed 07__talking_against_wall.mp4: 830 face(s) cropped into FF_real93.
# Processed 07__talking_angry_couch.mp4: 1620 face(s) cropped into FF_real94.
# Processed 07__walking_down_street_outside_angry.mp4: 639 face(s) cropped into FF_real95.
# Processed 07__walking_outside_cafe_disgusted.mp4: 482 face(s) cropped into FF_real96.
# Processed 07__walk_down_hall_angry.mp4: 596 face(s) cropped into FF_real97.
# Processed 08__exit_phone_room.mp4: 379 face(s) cropped into FF_real98.
# Processed 08__kitchen_pan.mp4: 607 face(s) cropped into FF_real99.
# Processed 08__kitchen_still.mp4: 1010 face(s) cropped into FF_real100.
# Processed 08__outside_talking_pan_laughing.mp4: 675 face(s) cropped into FF_real101.
# Processed 08__outside_talking_still_laughing.mp4: 884 face(s) cropped into FF_real102.
# Processed 08__podium_speech_happy.mp4: 1080 face(s) cropped into FF_real103.
# Processed 08__talking_against_wall.mp4: 1101 face(s) cropped into FF_real104.
# Processed 08__walking_down_street_outside_angry.mp4: 506 face(s) cropped into FF_real105.
# Processed 08__walking_outside_cafe_disgusted.mp4: 391 face(s) cropped into FF_real106.
# Processed 08__walk_down_hall_angry.mp4: 348 face(s) cropped into FF_real107.
# Processed 09__exit_phone_room.mp4: 379 face(s) cropped into FF_real108.
# Processed 09__kitchen_pan.mp4: 677 face(s) cropped into FF_real109.
# Processed 09__outside_talking_pan_laughing.mp4: 787 face(s) cropped into FF_real110.
# Processed 09__outside_talking_still_laughing.mp4: 923 face(s) cropped into FF_real111.
# Processed 09__podium_speech_happy.mp4: 1024 face(s) cropped into FF_real112.
# Processed 09__talking_against_wall.mp4: 975 face(s) cropped into FF_real113.
# Processed 09__talking_angry_couch.mp4: 1325 face(s) cropped into FF_real114.
# Processed 09__walking_down_street_outside_angry.mp4: 450 face(s) cropped into FF_real115.
# Processed 09__walk_down_hall_angry.mp4: 355 face(s) cropped into FF_real116.
# Processed 10__exit_phone_room.mp4: 313 face(s) cropped into FF_real117.
# Processed 10__kitchen_pan.mp4: 598 face(s) cropped into FF_real118.
# Processed 10__kitchen_still.mp4: 783 face(s) cropped into FF_real119.
# Processed 10__outside_talking_pan_laughing.mp4: 770 face(s) cropped into FF_real120.
# Processed 10__outside_talking_still_laughing.mp4: 790 face(s) cropped into FF_real121.
# Processed 10__podium_speech_happy.mp4: 993 face(s) cropped into FF_real122.
# Processed 10__talking_against_wall.mp4: 1016 face(s) cropped into FF_real123.
# Processed 10__talking_angry_couch.mp4: 1415 face(s) cropped into FF_real124.
# Processed 10__walking_down_street_outside_angry.mp4: 883 face(s) cropped into FF_real125.
# Processed 10__walking_outside_cafe_disgusted.mp4: 997 face(s) cropped into FF_real126.
# Processed 10__walk_down_hall_angry.mp4: 660 face(s) cropped into FF_real127.
# Processed 11__exit_phone_room.mp4: 808 face(s) cropped into FF_real128.
# Processed 11__kitchen_pan.mp4: 683 face(s) cropped into FF_real129.
# Processed 11__kitchen_still.mp4: 800 face(s) cropped into FF_real130.
# Processed 11__outside_talking_pan_laughing.mp4: 664 face(s) cropped into FF_real131.
# Processed 11__outside_talking_still_laughing.mp4: 772 face(s) cropped into FF_real132.
# Processed 11__podium_speech_happy.mp4: 1190 face(s) cropped into FF_real133.
# Processed 11__secret_conversation.mp4: 429 face(s) cropped into FF_real134.
# Processed 11__talking_against_wall.mp4: 880 face(s) cropped into FF_real135.
# Processed 11__talking_angry_couch.mp4: 1620 face(s) cropped into FF_real136.
# Processed 11__walking_down_street_outside_angry.mp4: 998 face(s) cropped into FF_real137.
# Processed 11__walking_outside_cafe_disgusted.mp4: 751 face(s) cropped into FF_real138.
# Processed 11__walk_down_hall_angry.mp4: 743 face(s) cropped into FF_real139.
# Processed 12__exit_phone_room.mp4: 867 face(s) cropped into FF_real140.
# Processed 12__hugging_happy.mp4: 961 face(s) cropped into FF_real141.
# Processed 12__kitchen_pan.mp4: 687 face(s) cropped into FF_real142.
# Processed 12__kitchen_still.mp4: 815 face(s) cropped into FF_real143.
# Processed 12__outside_talking_pan_laughing.mp4: 871 face(s) cropped into FF_real144.
# Processed 12__outside_talking_still_laughing.mp4: 855 face(s) cropped into FF_real145.
# Processed 12__podium_speech_happy.mp4: 1008 face(s) cropped into FF_real146.
# Processed 12__secret_conversation.mp4: 744 face(s) cropped into FF_real147.
# Processed 12__talking_against_wall.mp4: 880 face(s) cropped into FF_real148.
# Processed 12__talking_angry_couch.mp4: 1381 face(s) cropped into FF_real149.
# Processed 12__walking_and_outside_surprised.mp4: 1615 face(s) cropped into FF_real150.
# Processed 12__walking_down_indoor_hall_disgust.mp4: 2561 face(s) cropped into FF_real151.
# Processed 12__walking_down_street_outside_angry.mp4: 595 face(s) cropped into FF_real152.
# Processed 12__walking_outside_cafe_disgusted.mp4: 756 face(s) cropped into FF_real153.
# Processed 12__walk_down_hall_angry.mp4: 432 face(s) cropped into FF_real154.
# Processed 13__exit_phone_room.mp4: 529 face(s) cropped into FF_real155.
# Processed 13__hugging_happy.mp4: 582 face(s) cropped into FF_real156.
# Processed 13__kitchen_pan.mp4: 577 face(s) cropped into FF_real157.
# Processed 13__kitchen_still.mp4: 824 face(s) cropped into FF_real158.
# Processed 13__outside_talking_pan_laughing.mp4: 651 face(s) cropped into FF_real159.
# Processed 13__outside_talking_still_laughing.mp4: 860 face(s) cropped into FF_real160.
# Processed 13__podium_speech_happy.mp4: 997 face(s) cropped into FF_real161.
# Processed 13__secret_conversation.mp4: 270 face(s) cropped into FF_real162.
# Processed 13__talking_against_wall.mp4: 1045 face(s) cropped into FF_real163.
# Processed 13__talking_angry_couch.mp4: 1231 face(s) cropped into FF_real164.
# Processed 13__walking_and_outside_surprised.mp4: 1630 face(s) cropped into FF_real165.
# Processed 13__walking_down_indoor_hall_disgust.mp4: 2561 face(s) cropped into FF_real166.
# Processed 13__walking_down_street_outside_angry.mp4: 609 face(s) cropped into FF_real167.
# Processed 13__walking_outside_cafe_disgusted.mp4: 377 face(s) cropped into FF_real168.
# Processed 13__walk_down_hall_angry.mp4: 499 face(s) cropped into FF_real169.
# Processed 14__exit_phone_room.mp4: 669 face(s) cropped into FF_real170.
# Processed 14__hugging_happy.mp4: 67 face(s) cropped into FF_real171.
# Processed 14__kitchen_pan.mp4: 630 face(s) cropped into FF_real172.
# Processed 14__kitchen_still.mp4: 890 face(s) cropped into FF_real173.
# Processed 14__outside_talking_pan_laughing.mp4: 707 face(s) cropped into FF_real174.
# Processed 14__outside_talking_still_laughing.mp4: 924 face(s) cropped into FF_real175.
# Processed 14__podium_speech_happy.mp4: 1318 face(s) cropped into FF_real176.
# Processed 14__secret_conversation.mp4: 384 face(s) cropped into FF_real177.
# Processed 14__talking_against_wall.mp4: 970 face(s) cropped into FF_real178.
# Processed 14__talking_angry_couch.mp4: 1621 face(s) cropped into FF_real179.
# Processed 14__walking_and_outside_surprised.mp4: 1509 face(s) cropped into FF_real180.
# Processed 14__walking_down_indoor_hall_disgust.mp4: 2515 face(s) cropped into FF_real181.
# Processed 14__walking_down_street_outside_angry.mp4: 1325 face(s) cropped into FF_real182.
# Processed 14__walking_outside_cafe_disgusted.mp4: 743 face(s) cropped into FF_real183.
# Processed 14__walk_down_hall_angry.mp4: 587 face(s) cropped into FF_real184.
# Processed 15__exit_phone_room.mp4: 427 face(s) cropped into FF_real185.
# Processed 15__hugging_happy.mp4: 717 face(s) cropped into FF_real186.
# Processed 15__kitchen_pan.mp4: 584 face(s) cropped into FF_real187.
# Processed 15__kitchen_still.mp4: 865 face(s) cropped into FF_real188.
# Processed 15__outside_talking_pan_laughing.mp4: 681 face(s) cropped into FF_real189.
# Processed 15__outside_talking_still_laughing.mp4: 870 face(s) cropped into FF_real190.
# Processed 15__podium_speech_happy.mp4: 1424 face(s) cropped into FF_real191.
# Processed 15__talking_against_wall.mp4: 865 face(s) cropped into FF_real192.
# Processed 15__talking_angry_couch.mp4: 1339 face(s) cropped into FF_real193.
# Processed 15__walking_and_outside_surprised.mp4: 1516 face(s) cropped into FF_real194.
# Processed 15__walking_down_indoor_hall_disgust.mp4: 2425 face(s) cropped into FF_real195.
# Processed 15__walking_down_street_outside_angry.mp4: 408 face(s) cropped into FF_real196.
# Processed 15__walking_outside_cafe_disgusted.mp4: 547 face(s) cropped into FF_real197.
# Processed 15__walk_down_hall_angry.mp4: 423 face(s) cropped into FF_real198.
# Processed 16__exit_phone_room.mp4: 566 face(s) cropped into FF_real199.
# --- Face cropping complete ---
#
# --- Processing Fake videos from FaceForensic++ dataset ---
# Processed 01_02__outside_talking_still_laughing__YVGY8LOK.mp4: 723 face(s) cropped into FF_fake0.
# Processed 01_02__walk_down_hall_angry__YVGY8LOK.mp4: 217 face(s) cropped into FF_fake1.
# Processed 01_03__hugging_happy__ISF9SP4G.mp4: 567 face(s) cropped into FF_fake2.
# Processed 01_03__podium_speech_happy__480LQD1C.mp4: 898 face(s) cropped into FF_fake3.
# Processed 01_03__talking_against_wall__JZUXXFRB.mp4: 843 face(s) cropped into FF_fake4.
# Processed 01_11__meeting_serious__9OM3VE0Y.mp4: 1199 face(s) cropped into FF_fake5.
# Processed 01_11__secret_conversation__4OJNJLOO.mp4: 927 face(s) cropped into FF_fake6.
# Processed 01_11__talking_against_wall__9229VVZ3.mp4: 843 face(s) cropped into FF_fake7.
# Processed 01_11__walking_outside_cafe_disgusted__FAFWDR4W.mp4: 239 face(s) cropped into FF_fake8.
# Processed 01_12__outside_talking_pan_laughing__TNI7KUZ6.mp4: 288 face(s) cropped into FF_fake9.
# Processed 01_20__outside_talking_pan_laughing__OTGHOG4Z.mp4: 504 face(s) cropped into FF_fake10.
# Processed 01_20__outside_talking_still_laughing__FW94AIMJ.mp4: 725 face(s) cropped into FF_fake11.
# Processed 01_21__walk_down_hall_angry__03X7CELV.mp4: 225 face(s) cropped into FF_fake12.
# Processed 01_27__hugging_happy__ZYCZ30C0.mp4: 564 face(s) cropped into FF_fake13.
# Processed 01_27__outside_talking_still_laughing__ZYCZ30C0.mp4: 734 face(s) cropped into FF_fake14.
# Processed 01_27__walking_outside_cafe_disgusted__ZYCZ30C0.mp4: 222 face(s) cropped into FF_fake15.
# Processed 02_01__secret_conversation__YVGY8LOK.mp4: 590 face(s) cropped into FF_fake16.
# Processed 02_03__walking_down_street_outside_angry__QH3Y0IG0.mp4: 457 face(s) cropped into FF_fake17.
# Processed 02_03__walking_outside_cafe_disgusted__QH3Y0IG0.mp4: 498 face(s) cropped into FF_fake18.
# Processed 02_06__podium_speech_happy__N8OSN8P6.mp4: 1077 face(s) cropped into FF_fake19.
# Processed 02_06__talking_angry_couch__GH8TGTBS.mp4: 1270 face(s) cropped into FF_fake20.
# Processed 02_06__talking_angry_couch__MKZTXQ2T.mp4: 1277 face(s) cropped into FF_fake21.
# Processed 02_06__walking_and_outside_surprised__N8OSN8P6.mp4: 1491 face(s) cropped into FF_fake22.
# Processed 02_06__walking_down_indoor_hall_disgust__U6MDWIHG.mp4: 1594 face(s) cropped into FF_fake23.
# Processed 02_07__meeting_serious__1JCLEEBQ.mp4: 1474 face(s) cropped into FF_fake24.
# Processed 02_07__walking_and_outside_surprised__1VMZUH1W.mp4: 1847 face(s) cropped into FF_fake25.
# Processed 02_07__walking_down_street_outside_angry__O4SXNLRL.mp4: 484 face(s) cropped into FF_fake26.
# Processed 02_07__walk_down_hall_angry__U7DEOZNV.mp4: 207 face(s) cropped into FF_fake27.
# Processed 02_09__exit_phone_room__HIH8YA82.mp4: 263 face(s) cropped into FF_fake28.
# Processed 02_09__kitchen_pan__HIH8YA82.mp4: 569 face(s) cropped into FF_fake29.
# Processed 02_12__podium_speech_happy__9D2ZHEKW.mp4: 1059 face(s) cropped into FF_fake30.
# Processed 02_13__exit_phone_room__CP5HFV3K.mp4: 259 face(s) cropped into FF_fake31.
# Processed 02_13__outside_talking_pan_laughing__2YSYT2N3.mp4: 628 face(s) cropped into FF_fake32.
# Processed 02_13__podium_speech_happy__2YSYT2N3.mp4: 1076 face(s) cropped into FF_fake33.
# Processed 02_13__secret_conversation__CP5HFV3K.mp4: 33 face(s) cropped into FF_fake34.
# Processed 02_14__outside_talking_pan_laughing__3IUBEKCT.mp4: 635 face(s) cropped into FF_fake35.
# Processed 02_15__exit_phone_room__I8G2LWD1.mp4: 258 face(s) cropped into FF_fake36.
# Processed 02_15__exit_phone_room__MZWH8ATN.mp4: 260 face(s) cropped into FF_fake37.
# Processed 02_15__outside_talking_pan_laughing__I8G2LWD1.mp4: 635 face(s) cropped into FF_fake38.
# Processed 02_15__outside_talking_pan_laughing__SB6PMCO0.mp4: 628 face(s) cropped into FF_fake39.
# Processed 02_15__secret_conversation__MZWH8ATN.mp4: 38 face(s) cropped into FF_fake40.
# Processed 02_15__talking_against_wall__HTG660F8.mp4: 990 face(s) cropped into FF_fake41.
# Processed 02_15__talking_angry_couch__HTG660F8.mp4: 1268 face(s) cropped into FF_fake42.
# Processed 02_15__talking_angry_couch__I8G2LWD1.mp4: 1269 face(s) cropped into FF_fake43.
# Processed 02_15__walking_and_outside_surprised__HTG660F8.mp4: 1855 face(s) cropped into FF_fake44.
# Processed 02_15__walking_and_outside_surprised__I8G2LWD1.mp4: 1843 face(s) cropped into FF_fake45.
# Processed 02_15__walking_and_outside_surprised__MZWH8ATN.mp4: 1461 face(s) cropped into FF_fake46.
# Processed 02_15__walk_down_hall_angry__TN2CWM3K.mp4: 207 face(s) cropped into FF_fake47.
# Processed 02_18__exit_phone_room__OXMEEFUQ.mp4: 261 face(s) cropped into FF_fake48.
# Processed 02_18__outside_talking_pan_laughing__OXMEEFUQ.mp4: 637 face(s) cropped into FF_fake49.
# Processed 02_18__walking_down_street_outside_angry__21JTDDEL.mp4: 457 face(s) cropped into FF_fake50.
# Processed 02_21__kitchen_pan__Z0XHPQAR.mp4: 569 face(s) cropped into FF_fake51.
# Processed 02_21__talking_angry_couch__Z0XHPQAR.mp4: 1257 face(s) cropped into FF_fake52.
# Processed 02_25__talking_against_wall__Z7FQ69VP.mp4: 990 face(s) cropped into FF_fake53.
# Processed 02_27__hugging_happy__GVFLSZD5.mp4: 680 face(s) cropped into FF_fake54.
# Processed 02_27__walk_down_hall_angry__78M8S6M6.mp4: 207 face(s) cropped into FF_fake55.
# Processed 03_01__walking_and_outside_surprised__JZUXXFRB.mp4: 2148 face(s) cropped into FF_fake56.
# Processed 03_04__outside_talking_pan_laughing__T04P6ELC.mp4: 713 face(s) cropped into FF_fake57.
# Processed 03_04__talking_angry_couch__T04P6ELC.mp4: 1451 face(s) cropped into FF_fake58.
# Processed 03_06__meeting_serious__83ABVHC3.mp4: 1012 face(s) cropped into FF_fake59.
# Processed 03_06__podium_speech_happy__83ABVHC3.mp4: 840 face(s) cropped into FF_fake60.
# Processed 03_07__hugging_happy__BKLOCI1M.mp4: 811 face(s) cropped into FF_fake61.
# Processed 03_07__walking_down_indoor_hall_disgust__PWXXULHR.mp4: 1948 face(s) cropped into FF_fake62.
# Processed 03_07__walking_outside_cafe_disgusted__CDSNLDQ8.mp4: 649 face(s) cropped into FF_fake63.
# Processed 03_07__walking_outside_cafe_disgusted__IFSURI9X.mp4: 662 face(s) cropped into FF_fake64.
# Processed 03_07__walking_outside_cafe_disgusted__PWXXULHR.mp4: 708 face(s) cropped into FF_fake65.
# Processed 03_07__walk_down_hall_angry__6PHZRQ4H.mp4: 448 face(s) cropped into FF_fake66.
# Processed 03_07__walk_down_hall_angry__IFSURI9X.mp4: 447 face(s) cropped into FF_fake67.
# Processed 03_09__outside_talking_still_laughing__RCETIXYL.mp4: 940 face(s) cropped into FF_fake68.
# Processed 03_09__secret_conversation__RCETIXYL.mp4: 880 face(s) cropped into FF_fake69.
# Processed 03_11__exit_phone_room__P08VGHTA.mp4: 551 face(s) cropped into FF_fake70.
# Processed 03_11__talking_against_wall__P08VGHTA.mp4: 910 face(s) cropped into FF_fake71.
# Processed 03_13__kitchen_pan__GBYWJW06.mp4: 530 face(s) cropped into FF_fake72.
# Processed 03_13__meeting_serious__GBYWJW06.mp4: 1029 face(s) cropped into FF_fake73.
# Processed 03_13__meeting_serious__T3MZOI8X.mp4: 1034 face(s) cropped into FF_fake74.
# Processed 03_13__outside_talking_still_laughing__GBYWJW06.mp4: 940 face(s) cropped into FF_fake75.
# Processed 03_14__podium_speech_happy__Q9NSXM88.mp4: 840 face(s) cropped into FF_fake76.
# Processed 03_14__talking_against_wall__ZC2KYASW.mp4: 910 face(s) cropped into FF_fake77.
# Processed 03_14__walking_down_street_outside_angry__H0VQHGS3.mp4: 997 face(s) cropped into FF_fake78.
# Processed 03_14__walk_down_hall_angry__P1L5PF4I.mp4: 456 face(s) cropped into FF_fake79.
# Processed 03_15__kitchen_pan__AIOM1U5V.mp4: 531 face(s) cropped into FF_fake80.
# Processed 03_15__kitchen_pan__DNUJD8M2.mp4: 530 face(s) cropped into FF_fake81.
# Processed 03_15__outside_talking_pan_laughing__Y11NT1YX.mp4: 712 face(s) cropped into FF_fake82.
# Processed 03_15__outside_talking_still_laughing__DNUJD8M2.mp4: 943 face(s) cropped into FF_fake83.
# Processed 03_15__podium_speech_happy__DG8ITQO3.mp4: 840 face(s) cropped into FF_fake84.
# Processed 03_18__walking_and_outside_surprised__8HNSXOBW.mp4: 1523 face(s) cropped into FF_fake85.
# Processed 03_18__walking_outside_cafe_disgusted__22UBC0BS.mp4: 707 face(s) cropped into FF_fake86.
# Processed 03_21__exit_phone_room__YCSEBZO4.mp4: 564 face(s) cropped into FF_fake87.
# Processed 03_21__kitchen_pan__YCSEBZO4.mp4: 530 face(s) cropped into FF_fake88.
# Processed 03_21__meeting_serious__V53E3RVB.mp4: 1023 face(s) cropped into FF_fake89.
# Processed 03_21__secret_conversation__YCSEBZO4.mp4: 896 face(s) cropped into FF_fake90.
# Processed 03_26__kitchen_pan__WBSXBL82.mp4: 527 face(s) cropped into FF_fake91.
# Processed 03_26__kitchen_still__WBSXBL82.mp4: 956 face(s) cropped into FF_fake92.
# Processed 03_26__talking_against_wall__WBSXBL82.mp4: 910 face(s) cropped into FF_fake93.
# Processed 03_27__walking_down_indoor_hall_disgust__IL675GCI.mp4: 2890 face(s) cropped into FF_fake94.
# Processed 03_27__walk_down_hall_angry__IL675GCI.mp4: 447 face(s) cropped into FF_fake95.
# Processed 04_01__exit_phone_room__0XUW13RW.mp4: 381 face(s) cropped into FF_fake96.
# Processed 04_01__kitchen_still__6I623VU9.mp4: 840 face(s) cropped into FF_fake97.
# Processed 04_01__outside_talking_still_laughing__0XUW13RW.mp4: 812 face(s) cropped into FF_fake98.
# Processed 04_01__outside_talking_still_laughing__6I623VU9.mp4: 812 face(s) cropped into FF_fake99.
# Processed 04_01__secret_conversation__6I623VU9.mp4: 760 face(s) cropped into FF_fake100.
# Processed 04_06__kitchen_still__ZK95PQDE.mp4: 840 face(s) cropped into FF_fake101.
# Processed 04_07__exit_phone_room__ITC0C48B.mp4: 327 face(s) cropped into FF_fake102.
# Processed 04_07__kitchen_pan__XRK7FGZX.mp4: 473 face(s) cropped into FF_fake103.
# Processed 04_12__walking_down_street_outside_angry__96TQKDFJ.mp4: 454 face(s) cropped into FF_fake104.
# Processed 04_13__podium_speech_happy__00T3UYOR.mp4: 932 face(s) cropped into FF_fake105.
# Processed 04_13__secret_conversation__00T3UYOR.mp4: 732 face(s) cropped into FF_fake106.
# Processed 04_13__walking_down_street_outside_angry__00T3UYOR.mp4: 435 face(s) cropped into FF_fake107.
# Processed 04_13__walking_outside_cafe_disgusted__00T3UYOR.mp4: 366 face(s) cropped into FF_fake108.
# Processed 04_18__kitchen_still__NAXINA1N.mp4: 840 face(s) cropped into FF_fake109.
# Processed 04_21__walking_down_street_outside_angry__5Y31RZP8.mp4: 472 face(s) cropped into FF_fake110.
# Processed 04_26__outside_talking_still_laughing__WX836VLY.mp4: 813 face(s) cropped into FF_fake111.
# Processed 05_08__talking_against_wall__PRBCE28Z.mp4: 835 face(s) cropped into FF_fake112.
# Processed 05_16__exit_phone_room__B62WCGUN.mp4: 405 face(s) cropped into FF_fake113.
# Processed 05_16__walk_down_hall_angry__OSXCUOHX.mp4: 425 face(s) cropped into FF_fake114.
# Processed 05_16__walk_down_hall_angry__U9WZI5LK.mp4: 425 face(s) cropped into FF_fake115.
# Processed 05_17__hugging_happy__YTJYYDO9.mp4: 626 face(s) cropped into FF_fake116.
# Processed 05_17__walking_down_street_outside_angry__M3H96PDQ.mp4: 645 face(s) cropped into FF_fake117.
# Processed 05_28__exit_phone_room__U9LRLJ6N.mp4: 403 face(s) cropped into FF_fake118.
# Processed 05_28__kitchen_still__W3J028UG.mp4: 875 face(s) cropped into FF_fake119.
# Processed 06_02__podium_speech_happy__N8OSN8P6.mp4: 1251 face(s) cropped into FF_fake120.
# Processed 06_02__walk_down_hall_angry__37DH75GQ.mp4: 300 face(s) cropped into FF_fake121.
# Processed 06_03__talking_against_wall__4I8LRXWF.mp4: 845 face(s) cropped into FF_fake122.
# Processed 06_04__outside_talking_still_laughing__ZK95PQDE.mp4: 668 face(s) cropped into FF_fake123.
# Processed 06_04__walking_outside_cafe_disgusted__ZK95PQDE.mp4: 315 face(s) cropped into FF_fake124.
# Processed 06_07__exit_phone_room__NMGYPBXE.mp4: 258 face(s) cropped into FF_fake125.
# Processed 06_07__kitchen_pan__NMGYPBXE.mp4: 684 face(s) cropped into FF_fake126.
# Processed 06_07__walking_down_street_outside_angry__NMGYPBXE.mp4: 563 face(s) cropped into FF_fake127.
# Processed 06_11__walking_outside_cafe_disgusted__MX659QU8.mp4: 314 face(s) cropped into FF_fake128.
# Processed 06_12__outside_talking_pan_laughing__3K21NFNM.mp4: 586 face(s) cropped into FF_fake129.
# Processed 06_12__podium_speech_happy__0VR4Y891.mp4: 1235 face(s) cropped into FF_fake130.
# Processed 06_12__podium_speech_happy__3K21NFNM.mp4: 1241 face(s) cropped into FF_fake131.
# Processed 06_14__outside_talking_pan_laughing__8U9ULZDT.mp4: 617 face(s) cropped into FF_fake132.
# Processed 06_14__walking_and_outside_surprised__8U9ULZDT.mp4: 1500 face(s) cropped into FF_fake133.
# Processed 06_14__walking_down_indoor_hall_disgust__8U9ULZDT.mp4: 2029 face(s) cropped into FF_fake134.
# Processed 06_15__exit_phone_room__QRCD27P8.mp4: 258 face(s) cropped into FF_fake135.
# Processed 06_15__outside_talking_still_laughing__QRCD27P8.mp4: 713 face(s) cropped into FF_fake136.
# Processed 06_15__walking_and_outside_surprised__QRCD27P8.mp4: 1466 face(s) cropped into FF_fake137.
# Processed 06_18__outside_talking_pan_laughing__DEA1TCLN.mp4: 626 face(s) cropped into FF_fake138.
# Processed 06_18__outside_talking_still_laughing__M36D0OJT.mp4: 657 face(s) cropped into FF_fake139.
# Processed 06_18__podium_speech_happy__DEA1TCLN.mp4: 1254 face(s) cropped into FF_fake140.
# Processed 06_18__walk_down_hall_angry__LH0KWJKM.mp4: 300 face(s) cropped into FF_fake141.
# Processed 06_20__kitchen_pan__6SUW7063.mp4: 680 face(s) cropped into FF_fake142.
# Processed 06_25__outside_talking_pan_laughing__MI9BDQ7M.mp4: 590 face(s) cropped into FF_fake143.
# Processed 06_25__talking_angry_couch__MI9BDQ7M.mp4: 1177 face(s) cropped into FF_fake144.
# Processed 06_25__walking_and_outside_surprised__MI9BDQ7M.mp4: 1510 face(s) cropped into FF_fake145.
# Processed 06_26__kitchen_pan__L5BVR5L9.mp4: 682 face(s) cropped into FF_fake146.
# Processed 06_26__kitchen_still__L5BVR5L9.mp4: 915 face(s) cropped into FF_fake147.
# Processed 06_27__talking_angry_couch__JOG5PB18.mp4: 1178 face(s) cropped into FF_fake148.
# Processed 06_27__walking_and_outside_surprised__O7L5Z9U8.mp4: 1547 face(s) cropped into FF_fake149.
# Processed 07_02__talking_angry_couch__1H07DFQJ.mp4: 1568 face(s) cropped into FF_fake150.
# Processed 07_02__walking_down_street_outside_angry__O4SXNLRL.mp4: 579 face(s) cropped into FF_fake151.
# Processed 07_03__hugging_happy__7NGMD8FT.mp4: 717 face(s) cropped into FF_fake152.
# Processed 07_03__outside_talking_pan_laughing__IFSURI9X.mp4: 696 face(s) cropped into FF_fake153.
# Processed 07_03__podium_speech_happy__6PHZRQ4H.mp4: 1079 face(s) cropped into FF_fake154.
# Processed 07_03__secret_conversation__IFSURI9X.mp4: 109 face(s) cropped into FF_fake155.
# Processed 07_03__talking_angry_couch__WPT3Z2KN.mp4: 1545 face(s) cropped into FF_fake156.
# Processed 07_03__walking_outside_cafe_disgusted__F0YYEA5W.mp4: 466 face(s) cropped into FF_fake157.
# Processed 07_06__kitchen_pan__NMGYPBXE.mp4: 536 face(s) cropped into FF_fake158.
# Processed 07_06__outside_talking_still_laughing__NMGYPBXE.mp4: 855 face(s) cropped into FF_fake159.
# Processed 07_06__walking_down_street_outside_angry__NMGYPBXE.mp4: 561 face(s) cropped into FF_fake160.
# Processed 07_09__outside_talking_still_laughing__N9CWME71.mp4: 857 face(s) cropped into FF_fake161.
# Processed 07_09__walk_down_hall_angry__N9CWME71.mp4: 562 face(s) cropped into FF_fake162.
# Processed 07_12__outside_talking_still_laughing__0VN0A2T3.mp4: 613 face(s) cropped into FF_fake163.
# Processed 07_13__walking_outside_cafe_disgusted__RVQCPCJF.mp4: 422 face(s) cropped into FF_fake164.
# Processed 07_14__exit_phone_room__P9QFO50U.mp4: 421 face(s) cropped into FF_fake165.
# Processed 07_14__talking_against_wall__P9QFO50U.mp4: 759 face(s) cropped into FF_fake166.
# Processed 07_15__hugging_happy__9Z2MLKVX.mp4: 712 face(s) cropped into FF_fake167.
# Processed 07_20__outside_talking_pan_laughing__KV6Q7D6C.mp4: 697 face(s) cropped into FF_fake168.
# Processed 07_20__talking_against_wall__KV6Q7D6C.mp4: 744 face(s) cropped into FF_fake169.
# Processed 07_21__exit_phone_room__K7KXUHMU.mp4: 431 face(s) cropped into FF_fake170.
# Processed 07_21__outside_talking_still_laughing__K7KXUHMU.mp4: 834 face(s) cropped into FF_fake171.
# Processed 07_21__talking_against_wall__MKU99DVX.mp4: 652 face(s) cropped into FF_fake172.
# Processed 07_25__walk_down_hall_angry__PAE9HCA8.mp4: 433 face(s) cropped into FF_fake173.
# Processed 07_26__walking_down_street_outside_angry__FGNGC2GT.mp4: 540 face(s) cropped into FF_fake174.
# Processed 07_26__walk_down_hall_angry__FGNGC2GT.mp4: 543 face(s) cropped into FF_fake175.
# Processed 07_27__walking_down_street_outside_angry__3RH5PR6S.mp4: 578 face(s) cropped into FF_fake176.
# Processed 08_05__walk_down_hall_angry__FBICSP2C.mp4: 276 face(s) cropped into FF_fake177.
# Processed 08_16__podium_speech_happy__8Q7JCS95.mp4: 1071 face(s) cropped into FF_fake178.
# Processed 08_28__outside_talking_pan_laughing__8BC35RFU.mp4: 586 face(s) cropped into FF_fake179.
# Processed 09_01__talking_against_wall__O8HNNX43.mp4: 975 face(s) cropped into FF_fake180.
# Processed 09_01__walk_down_hall_angry__6TSGVLHA.mp4: 334 face(s) cropped into FF_fake181.
# Processed 09_02__walking_down_street_outside_angry__6KUOFMZW.mp4: 387 face(s) cropped into FF_fake182.
# Processed 09_02__walking_down_street_outside_angry__9TDCEK1Q.mp4: 425 face(s) cropped into FF_fake183.
# Processed 09_02__walk_down_hall_angry__6KUOFMZW.mp4: 307 face(s) cropped into FF_fake184.
# Processed 09_03__kitchen_pan__8DTEGQ54.mp4: 668 face(s) cropped into FF_fake185.
# Processed 09_03__talking_against_wall__8DTEGQ54.mp4: 975 face(s) cropped into FF_fake186.
# Processed 09_07__kitchen_pan__N9CWME71.mp4: 664 face(s) cropped into FF_fake187.
# Processed 09_13__kitchen_pan__21H6XSPE.mp4: 651 face(s) cropped into FF_fake188.
# Processed 09_13__outside_talking_pan_laughing__LPT427RY.mp4: 695 face(s) cropped into FF_fake189.
# Processed 09_18__outside_talking_pan_laughing__3VP8836C.mp4: 724 face(s) cropped into FF_fake190.
# Processed 09_20__kitchen_pan__98NUQ3E6.mp4: 653 face(s) cropped into FF_fake191.
# Processed 09_20__podium_speech_happy__O5X0AWR9.mp4: 1024 face(s) cropped into FF_fake192.
# Processed 09_20__talking_angry_couch__0IRM5ADD.mp4: 1324 face(s) cropped into FF_fake193.
# Processed 09_25__walking_down_street_outside_angry__5041ODBN.mp4: 408 face(s) cropped into FF_fake194.
# Processed 09_26__talking_against_wall__C3K20JOL.mp4: 975 face(s) cropped into FF_fake195.
# Processed 09_26__walk_down_hall_angry__QSE5A0GF.mp4: 336 face(s) cropped into FF_fake196.
# Processed 10_19__kitchen_still__IDX76N5R.mp4: 754 face(s) cropped into FF_fake197.
# Processed 10_22__kitchen_pan__EHARPYBT.mp4: 664 face(s) cropped into FF_fake198.
# Processed 10_22__kitchen_still__EHARPYBT.mp4: 865 face(s) cropped into FF_fake199.
# --- Face cropping complete ---

# %% [markdown]
# ### 2.3 Defining Paths and Creating Directories for the Test Dataset

# %%
# Defining base directory where the dataset resides
base_dir = os.getcwd() # Current working directory where my Jupyter Notebook is located

# Defining paths for dataset directories
real_videos_dir = os.path.join(base_dir, "Datasets", "SDFVD", "real")
fake_videos_dir = os.path.join(base_dir, "Datasets", "SDFVD", "fake")

# Defining paths for cropped faces directories
real_faces_dir = os.path.join(base_dir, "Cropped_Faces", "test", "real")
fake_faces_dir = os.path.join(base_dir, "Cropped_Faces", "test", "fake")

# Creating necessary directories if they don’t already exist
os.makedirs(real_faces_dir, exist_ok=True)
os.makedirs(fake_faces_dir, exist_ok=True)

print(f"Directories for Test:")
print(f"Real Videos Directory: {real_videos_dir}")
print(f"Fake Videos Directory: {fake_videos_dir}")
print(f"Real Faces Directory: {real_faces_dir}")
print(f"Fake Faces Directory: {fake_faces_dir}")
# Out:
# Directories for Test:
# Real Videos Directory: C:\Users\atul\Datasets\SDFVD\real
# Fake Videos Directory: C:\Users\atul\Datasets\SDFVD\fake
# Real Faces Directory: C:\Users\atul\Cropped_Faces\test\real
# Fake Faces Directory: C:\Users\atul\Cropped_Faces\test\fake

# %% [markdown]
# ### 2.2 Face Detection and Cropping from Dataset for Testing

# %%
# Initialize the face detector
detector = dlib.get_frontal_face_detector()

def crop_faces(input_dir, output_dir, dataset_name, face_size=(224, 224), is_real=True):
    """
    Detects and crops faces from videos in the input directory.
    Cropped faces are saved in specific folders with unique names in the output directory.

    Args:
    - input_dir (str): Path to the directory containing videos.
    - output_dir (str): Path to the directory to save cropped face images.
    - dataset_name (str): Prefix for naming folders and files (e.g., dataset name).
    - face_size (tuple): Dimensions to resize each face (width, height).
    - is_real (bool): Indicates whether the videos are from the "real" or "fake" category.
    """
    # Check if input and output directories exist
    if not os.path.exists(input_dir):
        print(f"Input directory {input_dir} does not exist. Skipping.")
        return
    os.makedirs(output_dir, exist_ok=True)

    # Supported video formats
    supported_formats = (".mp4", ".avi", ".mkv", ".mov")

    # Initialize folder counter
    folder_counter = 0

    # Looping through each file in the input directory
    for file in os.listdir(input_dir):
        if file.lower().endswith(supported_formats):  # Process only supported video files
            video_name = os.path.splitext(file)[0]  # Extract the video name (without extension)

            # Generate a unique folder name based on the dataset name and category
            category = "real" if is_real else "fake"
            folder_name = f"{dataset_name}_{category}{folder_counter}"
            folder_counter += 1

            # Create the unique folder
            folder_path = os.path.join(output_dir, folder_name)

            # Skip already processed videos
            if os.path.exists(folder_path) and len(os.listdir(folder_path)) > 0:
                print(f"Skipping already processed video: {file}")
                continue

            os.makedirs(folder_path, exist_ok=True)

            video_path = os.path.join(input_dir, file)
            cap = cv2.VideoCapture(video_path)  # Open the video file

            if not cap.isOpened():
                print(f"Failed to open video {file}. Skipping.")
                continue

            frame_count = 0
            cropped_count = 0  # Counter for cropped faces

            # Looping through frames in the video
            while cap.isOpened():
                ret, frame = cap.read()  # Read a frame
                if not ret:  # Exit when no more frames
                    break

                frame_count += 1
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert frame to grayscale
                faces = detector(gray)  # Detect faces in the frame

                # Save each detected face
                for i, face in enumerate(faces):
                    x, y, w, h = face.left(), face.top(), face.width(), face.height()

                    # Validate face coordinates to ensure they are within the frame bounds
                    x = max(0, x)
                    y = max(0, y)
                    w = min(frame.shape[1] - x, w)
                    h = min(frame.shape[0] - y, h)

                    if w <= 0 or h <= 0:  # Check if the cropped region is valid
                        print(f"Invalid face region in frame {frame_count}, video {file}. Skipping.")
                        continue

                    # Crop the face from the frame
                    cropped_face = frame[y:y+h, x:x+w]

                    # Resize the cropped face to the specified size
                    cropped_face = cv2.resize(cropped_face, face_size)

                    # Generate a unique filename for the cropped face
                    file_name = f"{folder_name}_frame{frame_count}_face{i}.jpg"
                    save_path = os.path.join(folder_path, file_name)

                    # Save the cropped face
                    cv2.imwrite(save_path, cropped_face)
                    cropped_count += 1  # Increment the cropped face counter

            cap.release()  # Release the video capture object
            print(f"Processed {file}: {cropped_count} face(s) cropped into {folder_name}.")
    print("--- Face cropping complete ---")

# Process real videos
print("--- Processing Real videos from SDFVD dataset ---")
crop_faces(real_videos_dir, real_faces_dir, "SDFVD", is_real=True)

# Process fake videos
print("\n--- Processing Fake videos from SDFVD dataset ---")
crop_faces(fake_videos_dir, fake_faces_dir, "SDFVD", is_real=False)
# Out:
# --- Processing Real videos from SDFVD dataset ---
# Skipping already processed video: v1.mp4
# Skipping already processed video: v10.mp4
# Skipping already processed video: v11.mp4
# Skipping already processed video: v12.mp4
# Skipping already processed video: v13.mp4
# Processed v14.mp4: 0 face(s) cropped into SDFVD_real5.
# Skipping already processed video: v15.mp4
# Skipping already processed video: v16.mp4
# Skipping already processed video: v17.mp4
# Skipping already processed video: v18.mp4
# Skipping already processed video: v19.mp4
# Skipping already processed video: v2.mp4
# Skipping already processed video: v20.mp4
# Skipping already processed video: v21.mp4
# Skipping already processed video: v22.mp4
# Skipping already processed video: v23.mp4
# Skipping already processed video: v24.mp4
# Skipping already processed video: v25.mp4
# Skipping already processed video: v26.mp4
# Processed v27.mp4: 0 face(s) cropped into SDFVD_real19.
# Skipping already processed video: v28.mp4
# Skipping already processed video: v29.mp4
# Skipping already processed video: v3.mp4
# Skipping already processed video: v30.mp4
# Skipping already processed video: v31.mp4
# Skipping already processed video: v32.mp4
# Skipping already processed video: v33.mp4
# Skipping already processed video: v34.mp4
# Skipping already processed video: v35.mp4
# Skipping already processed video: v36.mp4
# Skipping already processed video: v37.mp4
# Skipping already processed video: v38.mp4
# Skipping already processed video: v39.mp4
# Skipping already processed video: v4.mp4
# Skipping already processed video: v40.mp4
# Skipping already processed video: v41.mp4
# Skipping already processed video: v42.mp4
# Skipping already processed video: v43.mp4
# Skipping already processed video: v44.mp4
# Skipping already processed video: v45.mp4
# Skipping already processed video: v46.mp4
# Skipping already processed video: v47.mp4
# Skipping already processed video: v48.mp4
# Skipping already processed video: v49.mp4
# Skipping already processed video: v5.mp4
# Skipping already processed video: v50.mp4
# Skipping already processed video: v51.mp4
# Skipping already processed video: v52.mp4
# Skipping already processed video: v53.mp4
# Skipping already processed video: v6.mp4
# Skipping already processed video: v7.mp4
# Skipping already processed video: v8.mp4
# Skipping already processed video: v9.mp4
# --- Face cropping complete ---
#
# --- Processing Fake videos from SDFVD dataset ---
# Skipping already processed video: vs1.mp4
# Skipping already processed video: vs10.mp4
# Skipping already processed video: vs11.mp4
# Skipping already processed video: vs12.mp4
# Skipping already processed video: vs13.mp4
# Processed vs14.mp4: 0 face(s) cropped into SDFVD_fake5.
# Skipping already processed video: vs15.mp4
# Skipping already processed video: vs16.mp4
# Skipping already processed video: vs17.mp4
# Skipping already processed video: vs18.mp4
# Skipping already processed video: vs19.mp4
# Skipping already processed video: vs2.mp4
# Skipping already processed video: vs20.mp4
# Skipping already processed video: vs21.mp4
# Skipping already processed video: vs22.mp4
# Skipping already processed video: vs23.mp4
# Skipping already processed video: vs24.mp4
# Skipping already processed video: vs25.mp4
# Skipping already processed video: vs26.mp4
# Skipping already processed video: vs27.mp4
# Skipping already processed video: vs28.mp4
# Skipping already processed video: vs29.mp4
# Skipping already processed video: vs3.mp4
# Skipping already processed video: vs30.mp4
# Skipping already processed video: vs31.mp4
# Skipping already processed video: vs32.mp4
# Skipping already processed video: vs33.mp4
# Skipping already processed video: vs34.mp4
# Skipping already processed video: vs35.mp4
# Skipping already processed video: vs36.mp4
# Skipping already processed video: vs37.mp4
# Skipping already processed video: vs38.mp4
# Skipping already processed video: vs39.mp4
# Skipping already processed video: vs4.mp4
# Skipping already processed video: vs40.mp4
# Skipping already processed video: vs41.mp4
# Skipping already processed video: vs42.mp4
# Skipping already processed video: vs43.mp4
# Skipping already processed video: vs44.mp4
# Skipping already processed video: vs45.mp4
# Skipping already processed video: vs46.mp4
# Skipping already processed video: vs47.mp4
# Skipping already processed video: vs48.mp4
# Skipping already processed video: vs49.mp4
# Skipping already processed video: vs5.mp4
# Skipping already processed video: vs50.mp4
# Skipping already processed video: vs51.mp4
# Skipping already processed video: vs52.mp4
# Skipping already processed video: vs53.mp4
# Skipping already processed video: vs6.mp4
# Skipping already processed video: vs7.mp4
# Skipping already processed video: vs8.mp4
# Skipping already processed video: vs9.mp4
# --- Face cropping complete ---
